# %%
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# loading the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# scaling the features
X_train, X_test = X_train/255.0 , X_test/255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# %%
# building the model
model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\pr\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#compiling the model
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# training the model
training = model.fit(X_train, y_train_cat, epochs=10, validation_split=0.2)

#saving the model
model.save('best_mnist_model.h5')
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9236 - loss: 0.2640 - val_accuracy: 0.9567 - val_loss: 0.1425
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9658 - loss: 0.1157 - val_accuracy: 0.9672 - val_loss: 0.1114
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9760 - loss: 0.0795 - val_accuracy: 0.9706 - val_loss: 0.0976
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9819 - loss: 0.0588 - val_accuracy: 0.9726 - val_loss: 0.0941
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9851 - loss: 0.0465 - val_accuracy: 0.9739 - val_loss: 0.0937
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9881 - loss: 0.0352 - val_accuracy: 0.9774 - val_loss: 0.0886
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9902 - loss: 0.0290 - val_accuracy: 0.9767 - val_loss: 0.0899
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 5ms/step - accuracy: 0.9911 - loss: 0.0269 - val_accuracy: 0.9768 - val_loss: 0.0939
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9929 - loss: 0.0201 - val_accuracy: 0.9748 - val_loss: 0.1011
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9933 - loss: 0.0197 - val_accuracy: 0.9751 - val_loss: 0.1052
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test_cat)
print(f'test loss is: {test_loss:.4f}')
print(f'test accuracy is: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9788 - loss: 0.0850
# test loss is: 0.0850
# test accuracy is: 0.9788
