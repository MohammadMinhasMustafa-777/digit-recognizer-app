# %%
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
# Out:
# c:\Users\pr\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# loading the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# scaling the features
X_train, X_test = X_train/255.0 , X_test/255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# %%
# building the model
model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\pr\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#compiling the model
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# training the model
training = model.fit(X_train, y_train_cat, epochs=10, validation_split=0.2)

#saving the model
model.export("best_mnist_model")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9940 - loss: 0.0183 - val_accuracy: 0.9728 - val_loss: 0.1239
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9956 - loss: 0.0144 - val_accuracy: 0.9739 - val_loss: 0.1166
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9950 - loss: 0.0141 - val_accuracy: 0.9763 - val_loss: 0.1223
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9953 - loss: 0.0131 - val_accuracy: 0.9740 - val_loss: 0.1307
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.9956 - loss: 0.0128 - val_accuracy: 0.9762 - val_loss: 0.1265
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9960 - loss: 0.0114 - val_accuracy: 0.9724 - val_loss: 0.1435
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9959 - loss: 0.0115 - val_accuracy: 0.9741 - val_loss: 0.1359
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9959 - loss: 0.0137 - val_accuracy: 0.9734 - val_loss: 0.1451
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.9732 - val_loss: 0.1512
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9969 - loss: 0.0090 - val_accuracy: 0.9755 - val_loss: 0.1436
# INFO:tensorflow:Assets written to: best_mnist_model\assets
# INFO:tensorflow:Assets written to: best_mnist_model\assets
# Saved artifact at 'best_mnist_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   1708892675664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1708892673552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1708892676432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1708892674512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1708892670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1709345037712: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test_cat)
print(f'test loss is: {test_loss:.4f}')
print(f'test accuracy is: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9779 - loss: 0.1204
# test loss is: 0.1204
# test accuracy is: 0.9779
